# %%
import os

carpetas = [
    'TFM_Gentrificacion_Madrid/data/raw',
    'TFM_Gentrificacion_Madrid/data/processed',
    'TFM_Gentrificacion_Madrid/data/final',
    'TFM_Gentrificacion_Madrid/notebooks',
    'TFM_Gentrificacion_Madrid/outputs/figures',
    'TFM_Gentrificacion_Madrid/outputs/tables',
    'TFM_Gentrificacion_Madrid/memory'
]

for carpeta in carpetas:
    os.makedirs(carpeta, exist_ok=True)
    print(f'Creada: {carpeta}')
# Out:
# ✓ Creada: TFM_Gentrificacion_Madrid/data/raw
# ✓ Creada: TFM_Gentrificacion_Madrid/data/processed
# ✓ Creada: TFM_Gentrificacion_Madrid/data/final
# ✓ Creada: TFM_Gentrificacion_Madrid/notebooks
# ✓ Creada: TFM_Gentrificacion_Madrid/outputs/figures
# ✓ Creada: TFM_Gentrificacion_Madrid/outputs/tables
# ✓ Creada: TFM_Gentrificacion_Madrid/memory
#
# ¡Estructura creada correctamente!
